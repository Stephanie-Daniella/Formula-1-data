# %%
import pandas as pd
import numpy as np
from siuba import *
import os

# %%
LpTimess = pd.read_csv("lapTimess.csv")
LpTimess
# Out:
#         year  round                raceId   driverId  lap  position     time
# 0       2010      1    Bahrain Grand Prix     vettel    1         1  02:03.4
# 1       2010      1    Bahrain Grand Prix     alonso    1         2  02:05.4
# 2       2010      1    Bahrain Grand Prix      massa    1         3  02:06.8
# 3       2010      1    Bahrain Grand Prix    rosberg    1         4  02:08.1
# 4       2010      1    Bahrain Grand Prix   hamilton    1         5  02:08.6
# ...      ...    ...                   ...        ...  ...       ...      ...
# 291843  2022     22  Abu Dhabi Grand Prix       ocon   58         7  01:30.0
# 291844  2022     22  Abu Dhabi Grand Prix     stroll   58         8  01:31.3
# 291845  2022     22  Abu Dhabi Grand Prix  ricciardo   58         9  01:30.9
# 291846  2022     22  Abu Dhabi Grand Prix     vettel   58        10  01:30.4
# 291847  2022     22  Abu Dhabi Grand Prix    tsunoda   58        11  01:32.3
#
# [291848 rows x 7 columns]

# %%
LpTimess>>group_by(_.raceId)>>group_by(_.driverId)>>summarize(Promedio=_.time.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1621         try:
# -> 1622             x = float(x)
#    1623         except (TypeError, ValueError):
#
# ...
