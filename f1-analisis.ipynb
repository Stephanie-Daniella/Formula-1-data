# %%
import pandas as pd
import json
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'http://ergast.com/api/f1/2022/22.json'
response = requests.get(url)

# %%
content=json.loads(response.content)

# %%
df_results_2022=pd.DataFrame()
for race in range(1,23):
    url='http://ergast.com/api/f1/2022/{}/results.json'
    response=requests.get(url.format(race))
    content=json.loads(response.content)
    df_results_2022 = df_results_2022.append(content['MRData']['RaceTable']['Races'][0]['Results'])

# %%
df_results_2022
# Out:
#    number position positionText points  \
# 0      16        1            1     26
# 1      55        2            2     18
# 2      44        3            3     15
# 3      63        4            4     12
# 4      20        5            5     10
# ..    ...      ...          ...    ...
# 15     47       16           16      0
# 16     20       17           17      0
# 17     44       18           18      0
# 18      6       19           19      0
# 19     14       20            R      0
#
#                                                Driver  \
# 0   {'driverId': 'leclerc', 'permanentNumber': '16...
# 1   {'driverId': 'sainz', 'permanentNumber': '55',...
# 2   {'driverId': 'hamilton', 'permanentNumber': '4...
# 3   {'driverId': 'russell', 'permanentNumber': '63...
# 4   {'driverId': 'kevin_magnussen', 'permanentNumb...
# ..                                                ...
# 15  {'driverId': 'mick_schumacher', 'permanentNumb...
# 16  {'driverId': 'kevin_magnussen', 'permanentNumb...
# 17  {'driverId': 'hamilton', 'permanentNumber': '4...
# 18  {'driverId': 'latifi', 'permanentNumber': '6',...
# 19  {'driverId': 'alonso', 'permanentNumber': '14'...
#
#                                           Constructor grid laps  \
# 0   {'constructorId': 'ferrari', 'url': 'http://en...    1   57
# 1   {'constructorId': 'ferrari', 'url': 'http://en...    3   57
# 2   {'constructorId': 'mercedes', 'url': 'http://e...    5   57
# 3   {'constructorId': 'mercedes', 'url': 'http://e...    9   57
# 4   {'constructorId': 'haas', 'url': 'http://en.wi...    7   57
# ..                                                ...  ...  ...
# 15  {'constructorId': 'haas', 'url': 'http://en.wi...   12   57
# 16  {'constructorId': 'haas', 'url': 'http://en.wi...   16   57
# 17  {'constructorId': 'mercedes', 'url': 'http://e...    5   55
# 18  {'constructorId': 'williams', 'url': 'http://e...   20   55
# 19  {'constructorId': 'alpine', 'url': 'http://en....   10   27
#
#               status                                          Time  \
# 0           Finished  {'millis': '5853584', 'time': '1:37:33.584'}
# 1           Finished       {'millis': '5859182', 'time': '+5.598'}
# 2           Finished       {'millis': '5863259', 'time': '+9.675'}
# 3           Finished      {'millis': '5864795', 'time': '+11.211'}
# 4           Finished      {'millis': '5868338', 'time': '+14.754'}
# ..               ...                                           ...
# 15            +1 Lap                                           NaN
# 16            +1 Lap                                           NaN
# 17        Hydraulics                                           NaN
# 18  Collision damage                                           NaN
# 19        Water leak                                           NaN
#
#                                            FastestLap
# 0   {'rank': '1', 'lap': '51', 'Time': {'time': '1...
# 1   {'rank': '3', 'lap': '52', 'Time': {'time': '1...
# 2   {'rank': '5', 'lap': '53', 'Time': {'time': '1...
# 3   {'rank': '6', 'lap': '56', 'Time': {'time': '1...
# 4   {'rank': '8', 'lap': '53', 'Time': {'time': '1...
# ..                                                ...
# 15  {'rank': '12', 'lap': '39', 'Time': {'time': '...
# 16  {'rank': '20', 'lap': '40', 'Time': {'time': '...
# 17  {'rank': '11', 'lap': '42', 'Time': {'time': '...
# 18  {'rank': '14', 'lap': '45', 'Time': {'time': '...
# 19  {'rank': '17', 'lap': '24', 'Time': {'time': '...
#
# [440 rows x 11 columns]

# %%
df_results_2022['points']=df_results_2022.points.astype(int)

# %%
Conductores=df_results_2022['Driver'].apply(lambda x: x['driverId'])
Conductores
# Out:
# 0             leclerc
# 1               sainz
# 2            hamilton
# 3             russell
# 4     kevin_magnussen
#            ...
# 15    mick_schumacher
# 16    kevin_magnussen
# 17           hamilton
# 18             latifi
# 19             alonso
# Name: Driver, Length: 440, dtype: object

# %% [markdown]
# ## Actividad
# Sumaremos los puntos obtenidos por conductor
# ### Tabla de resultados

# %%
df_results_2022['Driver']=df_results_2022['Driver'].apply(lambda x: x['driverId'])

# %%
df_results_2022['points']=df_results_2022['points'].astype(int)
df_results_2022
# Out:
#    number position positionText  points           Driver  \
# 0      16        1            1      26          leclerc
# 1      55        2            2      18            sainz
# 2      44        3            3      15         hamilton
# 3      63        4            4      12          russell
# 4      20        5            5      10  kevin_magnussen
# ..    ...      ...          ...     ...              ...
# 15     47       16           16       0  mick_schumacher
# 16     20       17           17       0  kevin_magnussen
# 17     44       18           18       0         hamilton
# 18      6       19           19       0           latifi
# 19     14       20            R       0           alonso
#
#                                           Constructor grid laps  \
# 0   {'constructorId': 'ferrari', 'url': 'http://en...    1   57
# 1   {'constructorId': 'ferrari', 'url': 'http://en...    3   57
# 2   {'constructorId': 'mercedes', 'url': 'http://e...    5   57
# 3   {'constructorId': 'mercedes', 'url': 'http://e...    9   57
# 4   {'constructorId': 'haas', 'url': 'http://en.wi...    7   57
# ..                                                ...  ...  ...
# 15  {'constructorId': 'haas', 'url': 'http://en.wi...   12   57
# 16  {'constructorId': 'haas', 'url': 'http://en.wi...   16   57
# 17  {'constructorId': 'mercedes', 'url': 'http://e...    5   55
# 18  {'constructorId': 'williams', 'url': 'http://e...   20   55
# 19  {'constructorId': 'alpine', 'url': 'http://en....   10   27
#
#               status                                          Time  \
# 0           Finished  {'millis': '5853584', 'time': '1:37:33.584'}
# 1           Finished       {'millis': '5859182', 'time': '+5.598'}
# 2           Finished       {'millis': '5863259', 'time': '+9.675'}
# 3           Finished      {'millis': '5864795', 'time': '+11.211'}
# 4           Finished      {'millis': '5868338', 'time': '+14.754'}
# ..               ...                                           ...
# 15            +1 Lap                                           NaN
# 16            +1 Lap                                           NaN
# 17        Hydraulics                                           NaN
# 18  Collision damage                                           NaN
# 19        Water leak                                           NaN
#
#                                            FastestLap
# 0   {'rank': '1', 'lap': '51', 'Time': {'time': '1...
# 1   {'rank': '3', 'lap': '52', 'Time': {'time': '1...
# 2   {'rank': '5', 'lap': '53', 'Time': {'time': '1...
# 3   {'rank': '6', 'lap': '56', 'Time': {'time': '1...
# 4   {'rank': '8', 'lap': '53', 'Time': {'time': '1...
# ..                                                ...
# 15  {'rank': '12', 'lap': '39', 'Time': {'time': '...
# 16  {'rank': '20', 'lap': '40', 'Time': {'time': '...
# 17  {'rank': '11', 'lap': '42', 'Time': {'time': '...
# 18  {'rank': '14', 'lap': '45', 'Time': {'time': '...
# 19  {'rank': '17', 'lap': '24', 'Time': {'time': '...
#
# [440 rows x 11 columns]

# %%
df_results_2022.groupby(['Driver']).agg({'points':'sum'}).sort_values(by='points',ascending=False)
# Out:
#                  points
# Driver
# max_verstappen      433
# perez               291
# leclerc             291
# russell             262
# hamilton            233
# sainz               228
# norris              116
# ocon                 89
# alonso               81
# bottas               47
# vettel               37
# ricciardo            34
# gasly                23
# kevin_magnussen      21
# stroll               18
# tsunoda              12
# mick_schumacher      12
# zhou                  6
# albon                 4
# latifi                2
# de_vries              2
# hulkenberg            0

# %% [markdown]
# ## Ejercicio
# Ahora lo haremos pero por constructor

# %%
df_results_2022['Constructor']=df_results_2022['Constructor'].apply(lambda x: x['constructorId'])

# %%
df_results_2022.groupby(['Constructor']).agg({'points':'sum'}).sort_values(by='points',ascending=False)
# Out:
#               points
# Constructor
# red_bull         724
# ferrari          519
# mercedes         495
# alpine           170
# mclaren          150
# aston_martin      55
# alfa              53
# alphatauri        35
# haas              33
# williams           8

# %%
df_results_2022['Constructor']
# Out:
# 0      ferrari
# 1      ferrari
# 2     mercedes
# 3     mercedes
# 4         haas
#         ...
# 15        haas
# 16        haas
# 17    mercedes
# 18    williams
# 19      alpine
# Name: Constructor, Length: 440, dtype: object

# %% [markdown]
# ## Todas las carreras desde el 2010

# %%
url = 'http://ergast.com/api/f1/2012.json'
response = requests.get(url.format(race))
content=json.loads(response.content)

# %%
pd.DataFrame(content['MRData']['RaceTable']['Races'])
# Out:
#    season round                                                url  \
# 0    2012     1  http://en.wikipedia.org/wiki/2012_Australian_G...
# 1    2012     2  http://en.wikipedia.org/wiki/2012_Malaysian_Gr...
# 2    2012     3  http://en.wikipedia.org/wiki/2012_Chinese_Gran...
# 3    2012     4  http://en.wikipedia.org/wiki/2012_Bahrain_Gran...
# 4    2012     5  http://en.wikipedia.org/wiki/2012_Spanish_Gran...
# 5    2012     6  http://en.wikipedia.org/wiki/2012_Monaco_Grand...
# 6    2012     7  http://en.wikipedia.org/wiki/2012_Canadian_Gra...
# 7    2012     8  http://en.wikipedia.org/wiki/2012_European_Gra...
# 8    2012     9  http://en.wikipedia.org/wiki/2012_British_Gran...
# 9    2012    10  http://en.wikipedia.org/wiki/2012_German_Grand...
# 10   2012    11  http://en.wikipedia.org/wiki/2012_Hungarian_Gr...
# 11   2012    12  http://en.wikipedia.org/wiki/2012_Belgian_Gran...
# 12   2012    13  http://en.wikipedia.org/wiki/2012_Italian_Gran...
# 13   2012    14  http://en.wikipedia.org/wiki/2012_Singapore_Gr...
# 14   2012    15  http://en.wikipedia.org/wiki/2012_Japanese_Gra...
# 15   2012    16  http://en.wikipedia.org/wiki/2012_Korean_Grand...
# 16   2012    17  http://en.wikipedia.org/wiki/2012_Indian_Grand...
# 17   2012    18  http://en.wikipedia.org/wiki/2012_Abu_Dhabi_Gr...
# 18   2012    19  http://en.wikipedia.org/wiki/2012_United_State...
# 19   2012    20  http://en.wikipedia.org/wiki/2012_Brazilian_Gr...
#
#                     raceName  \
# 0      Australian Grand Prix
# 1       Malaysian Grand Prix
# 2         Chinese Grand Prix
# 3         Bahrain Grand Prix
# 4         Spanish Grand Prix
# 5          Monaco Grand Prix
# 6        Canadian Grand Prix
# 7        European Grand Prix
# 8         British Grand Prix
# 9          German Grand Prix
# 10      Hungarian Grand Prix
# 11        Belgian Grand Prix
# 12        Italian Grand Prix
# 13      Singapore Grand Prix
# 14       Japanese Grand Prix
# 15         Korean Grand Prix
# 16         Indian Grand Prix
# 17      Abu Dhabi Grand Prix
# 18  United States Grand Prix
# 19      Brazilian Grand Prix
#
#                                               Circuit        date       time
# 0   {'circuitId': 'albert_park', 'url': 'http://en...  2012-03-18  06:00:00Z
# 1   {'circuitId': 'sepang', 'url': 'http://en.wiki...  2012-03-25  08:00:00Z
# 2   {'circuitId': 'shanghai', 'url': 'http://en.wi...  2012-04-15  07:00:00Z
# 3   {'circuitId': 'bahrain', 'url': 'http://en.wik...  2012-04-22  12:00:00Z
# 4   {'circuitId': 'catalunya', 'url': 'http://en.w...  2012-05-13  12:00:00Z
# 5   {'circuitId': 'monaco', 'url': 'http://en.wiki...  2012-05-27  12:00:00Z
# 6   {'circuitId': 'villeneuve', 'url': 'http://en....  2012-06-10  18:00:00Z
# 7   {'circuitId': 'valencia', 'url': 'http://en.wi...  2012-06-24  12:00:00Z
# 8   {'circuitId': 'silverstone', 'url': 'http://en...  2012-07-08  12:00:00Z
# 9   {'circuitId': 'hockenheimring', 'url': 'http:/...  2012-07-22  12:00:00Z
# 10  {'circuitId': 'hungaroring', 'url': 'http://en...  2012-07-29  12:00:00Z
# 11  {'circuitId': 'spa', 'url': 'http://en.wikiped...  2012-09-02  12:00:00Z
# 12  {'circuitId': 'monza', 'url': 'http://en.wikip...  2012-09-09  12:00:00Z
# 13  {'circuitId': 'marina_bay', 'url': 'http://en....  2012-09-23  12:00:00Z
# 14  {'circuitId': 'suzuka', 'url': 'http://en.wiki...  2012-10-07  06:00:00Z
# 15  {'circuitId': 'yeongam', 'url': 'http://en.wik...  2012-10-14  06:00:00Z
# 16  {'circuitId': 'buddh', 'url': 'http://en.wikip...  2012-10-28  09:30:00Z
# 17  {'circuitId': 'yas_marina', 'url': 'http://en....  2012-11-04  13:00:00Z
# 18  {'circuitId': 'americas', 'url': 'http://en.wi...  2012-11-18  19:00:00Z
# 19  {'circuitId': 'interlagos', 'url': 'http://en....  2012-11-25  16:00:00Z

# %%
races = {'season':[],
        'round':[],
        'raceName':[],
        'circuitId':[],
        'lat':[],
        'long':[],
        'country':[],
        'date':[],
        'url':[]}

# %%
for year in range(2010,2023):
    url='http://ergast.com/api/f1/{}.json'
    response=requests.get(url.format(year))
    content=json.loads(response.content)
    
    for item in content['MRData']['RaceTable']['Races']:
            races['season'].append(int(item['season']))
            races['round'].append(int(item['round']))
            races['raceName'].append(item['raceName'])
            races['circuitId'].append(item['Circuit']['circuitId'])
            races['lat'].append(item['Circuit']['Location']['lat'])
            races['long'].append(item['Circuit']['Location']['long'])
            races['country'].append(item['Circuit']['Location']['country'])
            races['date'].append(item['date'])
            #races['url'].append(item['Circuit']['url'])
            races['url'].append(item['url'])

# %%
pd.DataFrame(races)
# Out:
#      season  round                  raceName    circuitId       lat      long  \
# 0      2010      1        Bahrain Grand Prix      bahrain   26.0325   50.5106
# 1      2010      2     Australian Grand Prix  albert_park  -37.8497   144.968
# 2      2010      3      Malaysian Grand Prix       sepang   2.76083   101.738
# 3      2010      4        Chinese Grand Prix     shanghai   31.3389    121.22
# 4      2010      5        Spanish Grand Prix    catalunya     41.57   2.26111
# ..      ...    ...                       ...          ...       ...       ...
# 254    2022     18       Japanese Grand Prix       suzuka   34.8431   136.541
# 255    2022     19  United States Grand Prix     americas   30.1328  -97.6411
# 256    2022     20    Mexico City Grand Prix    rodriguez   19.4042  -99.0907
# 257    2022     21      Brazilian Grand Prix   interlagos  -23.7036  -46.6997
# 258    2022     22      Abu Dhabi Grand Prix   yas_marina   24.4672   54.6031
#
#        country        date                                                url
# 0      Bahrain  2010-03-14  http://en.wikipedia.org/wiki/2010_Bahrain_Gran...
# 1    Australia  2010-03-28  http://en.wikipedia.org/wiki/2010_Australian_G...
# 2     Malaysia  2010-04-04  http://en.wikipedia.org/wiki/2010_Malaysian_Gr...
# 3        China  2010-04-18  http://en.wikipedia.org/wiki/2010_Chinese_Gran...
# 4        Spain  2010-05-09  http://en.wikipedia.org/wiki/2010_Spanish_Gran...
# ..         ...         ...                                                ...
# 254      Japan  2022-10-09  http://en.wikipedia.org/wiki/2022_Japanese_Gra...
# 255        USA  2022-10-23  http://en.wikipedia.org/wiki/2022_United_State...
# 256     Mexico  2022-10-30  http://en.wikipedia.org/wiki/2022_Mexican_Gran...
# 257     Brazil  2022-11-13  http://en.wikipedia.org/wiki/2022_Brazilian_Gr...
# 258        UAE  2022-11-20  http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Gr...
#
# [259 rows x 9 columns]

# %% [markdown]
# ## Actividad
# Tabla con year y url

# %%
url='http://ergast.com/api/f1/seasons.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
season ={'temporada':[],'url':[]}
for item in content['MRData']['SeasonTable']['Seasons']:
    season['temporada'].append(int(item['season']))
    season['url'].append(item['url'])
pd.DataFrame(season)
# Out:
#     temporada                                                url
# 0        1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1        1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2        1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3        1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4        1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# 5        1955  http://en.wikipedia.org/wiki/1955_Formula_One_...
# 6        1956  http://en.wikipedia.org/wiki/1956_Formula_One_...
# 7        1957  http://en.wikipedia.org/wiki/1957_Formula_One_...
# 8        1958  http://en.wikipedia.org/wiki/1958_Formula_One_...
# 9        1959  http://en.wikipedia.org/wiki/1959_Formula_One_...
# 10       1960  http://en.wikipedia.org/wiki/1960_Formula_One_...
# 11       1961  http://en.wikipedia.org/wiki/1961_Formula_One_...
# 12       1962  http://en.wikipedia.org/wiki/1962_Formula_One_...
# 13       1963  http://en.wikipedia.org/wiki/1963_Formula_One_...
# 14       1964  http://en.wikipedia.org/wiki/1964_Formula_One_...
# 15       1965  http://en.wikipedia.org/wiki/1965_Formula_One_...
# 16       1966  http://en.wikipedia.org/wiki/1966_Formula_One_...
# 17       1967  http://en.wikipedia.org/wiki/1967_Formula_One_...
# 18       1968  http://en.wikipedia.org/wiki/1968_Formula_One_...
# 19       1969  http://en.wikipedia.org/wiki/1969_Formula_One_...
# 20       1970  http://en.wikipedia.org/wiki/1970_Formula_One_...
# 21       1971  http://en.wikipedia.org/wiki/1971_Formula_One_...
# 22       1972  http://en.wikipedia.org/wiki/1972_Formula_One_...
# 23       1973  http://en.wikipedia.org/wiki/1973_Formula_One_...
# 24       1974  http://en.wikipedia.org/wiki/1974_Formula_One_...
# 25       1975  http://en.wikipedia.org/wiki/1975_Formula_One_...
# 26       1976  http://en.wikipedia.org/wiki/1976_Formula_One_...
# 27       1977  http://en.wikipedia.org/wiki/1977_Formula_One_...
# 28       1978  http://en.wikipedia.org/wiki/1978_Formula_One_...
# 29       1979  http://en.wikipedia.org/wiki/1979_Formula_One_...

# %% [markdown]
# ### Exportar a excel o csv
# La diferencia con excel sería:
#
# pd.DataFrame(races).to_excel('races.xlsx',index=False)

# %%
pd.DataFrame(races).to_csv('races.csv',index=False)

# %%
pd.DataFrame(season).to_csv('season.csv',index=False)

# %% [markdown]
# # Tarea 1
# Crear el scrip que genere 4 archivos csv que contengan la información de las siguientes tablas:
#
# drivers constructors circuits qualifying

# %% [markdown]
# ### Drivers

# %%
for year in range(2010,2023):
    url='http://ergast.com/api/f1/{}/drivers.json'
    response=requests.get(url.format(year))
    content=json.loads(response.content)

# %%
#drivers ={'driverId':[],'driverRef':[],'number':[],'code':[],'forname':[],'sumame':[],'dob':[],'nationality':[],'url':[]}
drivers ={'driverId':[],'number':[],'code':[],'forname':[],'sumame':[],'dob':[],'nationality':[],'url':[]}
for item in content['MRData']['DriverTable']['Drivers']:
    drivers['driverId'].append(item['driverId'])
    #drivers['driverRef'].append(item['driverRef'])
    drivers['number'].append(int(item['permanentNumber']))
    drivers['code'].append(item['code'])
    drivers['forname'].append(item['familyName'])
    drivers['sumame'].append(item['givenName'])
    drivers['dob'].append(item['dateOfBirth'])
    drivers['nationality'].append(item['nationality'])
    drivers['url'].append(item['url'])
pd.DataFrame(drivers)
# Out:
#            driverId  number code     forname     sumame         dob  \
# 0             albon      23  ALB       Albon  Alexander  1996-03-23
# 1            alonso      14  ALO      Alonso   Fernando  1981-07-29
# 2            bottas      77  BOT      Bottas   Valtteri  1989-08-28
# 3          de_vries      45  DEV    de Vries       Nyck  1995-02-06
# 4             gasly      10  GAS       Gasly     Pierre  1996-02-07
# 5          hamilton      44  HAM    Hamilton      Lewis  1985-01-07
# 6        hulkenberg      27  HUL  Hülkenberg       Nico  1987-08-19
# 7            latifi       6  LAT      Latifi   Nicholas  1995-06-29
# 8           leclerc      16  LEC     Leclerc    Charles  1997-10-16
# 9   kevin_magnussen      20  MAG   Magnussen      Kevin  1992-10-05
# 10           norris       4  NOR      Norris      Lando  1999-11-13
# 11             ocon      31  OCO        Ocon    Esteban  1996-09-17
# 12            perez      11  PER       Pérez     Sergio  1990-01-26
# 13        ricciardo       3  RIC   Ricciardo     Daniel  1989-07-01
# 14          russell      63  RUS     Russell     George  1998-02-15
# 15            sainz      55  SAI       Sainz     Carlos  1994-09-01
# 16  mick_schumacher      47  MSC  Schumacher       Mick  1999-03-22
# 17           stroll      18  STR      Stroll      Lance  1998-10-29
# 18          tsunoda      22  TSU     Tsunoda       Yuki  2000-05-11
# 19   max_verstappen      33  VER  Verstappen        Max  1997-09-30
# 20           vettel       5  VET      Vettel  Sebastian  1987-07-03
# 21             zhou      24  ZHO        Zhou     Guanyu  1999-05-30
#
#    nationality                                                url
# 0         Thai       http://en.wikipedia.org/wiki/Alexander_Albon
# 1      Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 2      Finnish       http://en.wikipedia.org/wiki/Valtteri_Bottas
# 3        Dutch         http://en.wikipedia.org/wiki/Nyck_de_Vries
# 4       French          http://en.wikipedia.org/wiki/Pierre_Gasly
# 5      British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 6       German  http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg
# 7     Canadian       http://en.wikipedia.org/wiki/Nicholas_Latifi
# 8   Monegasque       http://en.wikipedia.org/wiki/Charles_Leclerc
# 9       Danish       http://en.wikipedia.org/wiki/Kevin_Magnussen
# 10     British          http://en.wikipedia.org/wiki/Lando_Norris
# 11      French          http://en.wikipedia.org/wiki/Esteban_Ocon
# 12     Mexican     http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez
# 13  Australian      http://en.wikipedia.org/wiki/Daniel_Ricciardo
# 14     British  http://en.wikipedia.org/wiki/George_Russell_%2...
# 15     Spanish      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# 16      German       http://en.wikipedia.org/wiki/Mick_Schumacher
# 17    Canadian          http://en.wikipedia.org/wiki/Lance_Stroll
# 18    Japanese          http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 19       Dutch        http://en.wikipedia.org/wiki/Max_Verstappen
# 20      German      http://en.wikipedia.org/wiki/Sebastian_Vettel
# 21     Chinese           http://en.wikipedia.org/wiki/Guanyu_Zhou

# %%
pd.DataFrame(drivers).to_csv('drivers.csv',index=False)

# %% [markdown]
# ### constructors

# %%
for year in range(2010,2023):
    url='http://ergast.com/api/f1/{}/constructors.json'
    response=requests.get(url.format(year))
    content=json.loads(response.content)

# %%
#constructors ={'constructorId':[],'constructorRef':[],'name':[],'nationality':[],'url':[]}
constructors ={'constructorId':[],'name':[],'nationality':[],'url':[]}
for item in content['MRData']['ConstructorTable']['Constructors']:
    constructors['constructorId'].append(item['constructorId'])
    #constructors['driverRef'].append(item['driverRef'])
    constructors['name'].append(item['name'])
    constructors['nationality'].append(item['nationality'])
    constructors['url'].append(item['url'])
pd.DataFrame(constructors)
# Out:
#   constructorId            name nationality  \
# 0          alfa      Alfa Romeo       Swiss
# 1    alphatauri      AlphaTauri     Italian
# 2        alpine  Alpine F1 Team      French
# 3  aston_martin    Aston Martin     British
# 4       ferrari         Ferrari     Italian
# 5          haas    Haas F1 Team    American
# 6       mclaren         McLaren     British
# 7      mercedes        Mercedes      German
# 8      red_bull        Red Bull    Austrian
# 9      williams        Williams     British
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 1   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 2        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 3  http://en.wikipedia.org/wiki/Aston_Martin_in_F...
# 4      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 5          http://en.wikipedia.org/wiki/Haas_F1_Team
# 6               http://en.wikipedia.org/wiki/McLaren
# 7  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 8       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...

# %%
pd.DataFrame(constructors).to_csv('constructors.csv',index=False)

# %% [markdown]
# ### circuits

# %%
for year in range(2010,2023):
    url='http://ergast.com/api/f1/{}/circuits.json'
    response=requests.get(url.format(year))
    content=json.loads(response.content)

# %%
content['MRData']['CircuitTable']['Circuits'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27560\2260914608.py in <module>
# ----> 1 content['MRData']['CircuitTable']['Circuits'].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
#cicuits ={'circuitId':[],'cicuitsRef':[],'name':[],'location':[],'country':[],'lat':[],'lng':[],'alt':[],'url':[]}
circuits ={'circuitId':[],'name':[],'location':[],'country':[],'lat':[],'lng':[],'url':[]}
for item in content['MRData']['CircuitTable']['Circuits']:
    circuits['circuitId'].append(item['circuitId'])
    #circuits['driverRef'].append(item['driverRef'])
    circuits['lat'].append(float(item['Location']['lat']))
    circuits['lng'].append(float(item['Location']['long']))
    circuits['location'].append(item['Location']['locality'])
    circuits['country'].append(item['Location']['country'])
    #circuits['alt'].append(item['Location']['alt'])
    circuits['name'].append(item['circuitName'])
    circuits['url'].append(item['url'])
pd.DataFrame(circuits)
# Out:
#         circuitId                            name      location       country  \
# 0     albert_park  Albert Park Grand Prix Circuit     Melbourne     Australia
# 1        americas         Circuit of the Americas        Austin           USA
# 2         bahrain   Bahrain International Circuit        Sakhir       Bahrain
# 3            baku               Baku City Circuit          Baku    Azerbaijan
# 4       catalunya  Circuit de Barcelona-Catalunya      Montmeló         Spain
# 5     hungaroring                     Hungaroring      Budapest       Hungary
# 6           imola   Autodromo Enzo e Dino Ferrari         Imola         Italy
# 7      interlagos      Autódromo José Carlos Pace     São Paulo        Brazil
# 8          jeddah         Jeddah Corniche Circuit        Jeddah  Saudi Arabia
# 9      marina_bay       Marina Bay Street Circuit    Marina Bay     Singapore
# 10          miami   Miami International Autodrome         Miami           USA
# 11         monaco               Circuit de Monaco   Monte-Carlo        Monaco
# 12          monza    Autodromo Nazionale di Monza         Monza         Italy
# 13  red_bull_ring                   Red Bull Ring     Spielberg       Austria
# 14         ricard             Circuit Paul Ricard  Le Castellet        France
# 15      rodriguez    Autódromo Hermanos Rodríguez   Mexico City        Mexico
# 16    silverstone             Silverstone Circuit   Silverstone            UK
# 17            spa    Circuit de Spa-Francorchamps           Spa       Belgium
# 18         suzuka                  Suzuka Circuit        Suzuka         Japan
# 19     villeneuve       Circuit Gilles Villeneuve      Montreal        Canada
# 20     yas_marina              Yas Marina Circuit     Abu Dhabi           UAE
# 21      zandvoort          Circuit Park Zandvoort     Zandvoort   Netherlands
#
#         lat        lng                                                url
# 0  -37.8497  144.96800  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   30.1328  -97.64110  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2   26.0325   50.51060  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3   40.3725   49.85330     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 4   41.5700    2.26111  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 5   47.5789   19.24860           http://en.wikipedia.org/wiki/Hungaroring
# 6   44.3439   11.71670  http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 7  -23.7036  -46.69970  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 8   21.6319   39.10440  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 9    1.2914  103.86400  http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 10  25.9581  -80.23890  http://en.wikipedia.org/wiki/Miami_Internation...
# 11  43.7347    7.42056     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 12  45.6156    9.28111  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 13  47.2197   14.76470         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 14  43.2506    5.79167   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 15  19.4042  -99.09070  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 16  52.0786   -1.01694   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 17  50.4372    5.97139  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 18  34.8431  136.54100        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 19  45.5000  -73.52280  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 20  24.4672   54.60310    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 21  52.3888    4.54092     http://en.wikipedia.org/wiki/Circuit_Zandvoort

# %%
pd.DataFrame(circuits).to_csv('circuits.csv',index=False)

# %% [markdown]
# ### qualifying

# %%
for year in range(2010,2023):
    url='http://ergast.com/api/f1/{}/qualifying.json'
    response=requests.get(url.format(year))
    content=json.loads(response.content)

# %%
#qualifying ={'qualifyingId':[],'raceId':[],'driverId':[],'constructorId':[],'number':[],'position':[],'Q1':[],'Q2':[],'Q3':[]}
qualifying ={'driverId':[],'constructorId':[],'number':[],'position':[],'Q1':[],'Q2':[],'Q3':[]}
for item in content['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
    #qualifying['qualifyingId'].append(item['qualifyingId'])
    #qualifying['raceId'].append(item['driverRef'])
    qualifying['driverId'].append(item['Driver']['driverId'])
    qualifying['constructorId'].append(item['Constructor']['constructorId'])
    qualifying['number'].append(int(item['number']))
    qualifying['position'].append(int(item['position']))
    qualifying['Q1'].append(item['Q1'])
    qualifying['Q2'].append(item['Q2'])
    qualifying['Q3'].append(item['Q3'])
for item in content['MRData']['RaceTable']['Races'][1]['QualifyingResults']:
    #qualifying['qualifyingId'].append(item['qualifyingId'])
    #qualifying['raceId'].append(item['driverRef'])
    qualifying['driverId'].append(item['Driver']['driverId'])
    qualifying['constructorId'].append(item['Constructor']['constructorId'])
    qualifying['number'].append(int(item['number']))
    qualifying['position'].append(int(item['position']))
    qualifying['Q1'].append(item['Q1'])
    qualifying['Q2'].append(item['Q2'])
    qualifying['Q3'].append(item['Q3'])
pd.DataFrame(qualifying)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27560\949052864.py in <module>
#      10     qualifying['Q1'].append(item['Q1'])
#      11     qualifying['Q2'].append(item['Q2'])
# ---> 12     qualifying['Q3'].append(item['Q3'])
#      13 for item in content['MRData']['RaceTable']['Races'][1]['QualifyingResults']:
#      14     #qualifying['qualifyingId'].append(item['qualifyingId'])
#
# KeyError: 'Q3'

# %%
content['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0].keys()
# Out:
# dict_keys(['number', 'position', 'Driver', 'Constructor', 'Q1', 'Q2', 'Q3'])

# %%
pd.DataFrame(qualifying).to_csv('qualifying.csv',index=False)
